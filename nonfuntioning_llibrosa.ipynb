# %%
# non working concentric

# %%
# # Load an audio file
# y, sr = librosa.load('09 Purple Rain.wav', sr=None)

# # Extract features
# melspectrogram = librosa.feature.melspectrogram(y=y, sr=sr)
# chromagram = librosa.feature.chroma_stft(y=y, sr=sr)
# spectral_contrast = librosa.feature.spectral_contrast(y=y, sr=sr)
# tonnetz = librosa.feature.tonnetz(y=y, sr=sr)
# harmonic, percussive = librosa.effects.hpss(y)

# # Convert to decibels
# melspectrogram_db = librosa.power_to_db(melspectrogram, ref=np.max)

# # Plot the figure
# fig, ax = plt.subplots(figsize=(12, 8), subplot_kw={'projection': 'polar'})

# # Define a list of features to plot
# features = [melspectrogram_db, chromagram, spectral_contrast, tonnetz, harmonic]
# feature_names = ['Mel-Spectrogram', 'Chromagram', 'Spectral Contrast', 'Tonnetz', 'Harmonic']

# # Radius increment
# radius_increment = 0.2

# for i, feature in enumerate(features):
#     # Normalize the feature
#     feature = (feature - np.min(feature)) / (np.max(feature) - np.min(feature))
   
#     # Make the feature array have the same number of columns (time) as the longest feature
#     feature = np.pad(feature, ((0, 0), (0, max(0, features[0].shape[1] - feature.shape[1]))), mode='constant')
   
#     # Convert to decibels if not already done
#     if i == 0:
#         feature = librosa.power_to_db(feature, ref=np.max)
   
#     # Create a radius offset for each feature to plot them as concentric circles
#     radius_offset = i * radius_increment
   
#     # Create theta (angle) and r (radius) for the plot
#     theta = np.linspace(0, 2 * np.pi, feature.shape[1])
#     r = np.linspace(radius_offset, radius_offset + radius_increment, feature.shape[0])
   
#     # Create meshgrid for theta and r
#     r, theta = np.meshgrid(r, theta)
   
#     # Plot the feature
#     ax.pcolormesh(theta, r, feature, cmap='viridis')

# ax.set_ylim(0, radius_offset + radius_increment)
# ax.set_title('Concentric Circles Representing Different Audio Features', va='bottom')
# plt.show()

# %%
# import librosa
# import numpy as np
# import matplotlib.pyplot as plt

# # Load the audio file
# y, sr = librosa.load('09 Purple Rain.wav', sr=22050)  # Reduced sampling rate

# # Extract features
# melspectrogram = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=64, hop_length=1024)
# chromagram = librosa.feature.chroma_stft(y=y, sr=sr, hop_length=1024)
# spectral_contrast = librosa.feature.spectral_contrast(y=y, sr=sr, hop_length=1024)
# tonnetz = librosa.feature.tonnetz(y=y, sr=sr)
# harmonic, percussive = librosa.effects.hpss(y)

# # Convert to decibels for the melspectrogram
# melspectrogram_db = librosa.power_to_db(melspectrogram, ref=np.max)

# # Normalize and prepare for padding
# features = [melspectrogram_db, chromagram, spectral_contrast, tonnetz, harmonic]
# max_length = max(f.shape[1] if f.ndim > 1 else f.shape[0] for f in features)  # Find the max length
# features_padded = []

# for f in features:
#     if f.ndim == 1:
#         # 1D feature
#         padded = np.pad(f, (0, max_length - f.shape[0]), mode='constant', constant_values=0)
#         padded = padded[np.newaxis, :]
#     else:
#         # 2D feature
#         padded = np.pad(f, ((0, 0), (0, max_length - f.shape[1])), mode='constant', constant_values=0)
#     features_padded.append(padded)

# # Plotting
# fig, ax = plt.subplots(figsize=(10, 10), subplot_kw={'projection': 'polar'})
# radius_increment = 0.2
# for i, feature in enumerate(features_padded):
#     radius_offset = i * radius_increment
#     theta = np.linspace(0, 2 * np.pi, feature.shape[1])
#     r = np.linspace(radius_offset, radius_offset + radius_increment, feature.shape[0])
#     theta, r = np.meshgrid(theta, r)
#     ax.pcolormesh(theta, r, feature, shading='flat')

# ax.set_title('Concentric Circles Representing Different Audio Features', va='bottom')
# plt.show()

# %%
# import librosa
# import numpy as np
# import matplotlib.pyplot as plt

# # Load a segment of the audio file
# y, sr = librosa.load('09 Purple Rain.wav', sr=22050, duration=60)  # Load only the first 60 seconds

# # Extract features with larger hop_length and fewer mel bands
# melspectrogram = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=32, hop_length=2048)
# chromagram = librosa.feature.chroma_stft(y=y, sr=sr, n_chroma=12, hop_length=2048)
# spectral_contrast = librosa.feature.spectral_contrast(y=y, sr=sr, hop_length=2048)
# tonnetz = librosa.feature.tonnetz(y=y, sr=sr)
# harmonic, percussive = librosa.effects.hpss(y)

# # Convert to decibels for the melspectrogram
# melspectrogram_db = librosa.power_to_db(melspectrogram, ref=np.max)

# # Normalize and prepare for visualization
# features = [melspectrogram_db, chromagram, spectral_contrast, tonnetz, harmonic]
# max_length = 500  # Pad or trim to a fixed length for visualization
# features_padded = []

# for f in features:
#     if f.ndim == 1:
#         # 1D feature
#         padded = np.pad(f, (0, max(0, max_length - f.shape[0])), mode='constant', constant_values=0)
#         padded = padded[np.newaxis, :]
#     else:
#         # 2D feature
#         length = min(max_length, f.shape[1])  # Limit to max_length or use actual length if shorter
#         padded = f[:, :length]  # Trim or use full length if shorter than max_length
#         if padded.shape[1] < max_length:
#             padded = np.pad(padded, ((0, 0), (0, max_length - padded.shape[1])), mode='constant', constant_values=0)
#     features_padded.append(padded)

# # Plotting
# fig, ax = plt.subplots(figsize=(10, 10), subplot_kw={'projection': 'polar'})
# radius_increment = 0.1  # Smaller increment if visual clarity is sufficient
# for i, feature in enumerate(features_padded):
#     radius_offset = i * radius_increment
#     theta = np.linspace(0, 2 * np.pi, feature.shape[1])

# %%
# import librosa
# import matplotlib.pyplot as plt
# import numpy as np

# # Load the audio file
# y, sr = librosa.load('01 Smells Like Teen Spirit.wav', sr=None)

# # Extract features
# melspectrogram = librosa.feature.melspectrogram(y=y, sr=sr)
# chromagram = librosa.feature.chroma_stft(y=y, sr=sr)
# spectral_contrast = librosa.feature.spectral_contrast(y=y, sr=sr)
# tonnetz = librosa.feature.tonnetz(y=y, sr=sr)
# harmonic, percussive = librosa.effects.hpss(y)

# # Convert to decibels
# melspectrogram_db = librosa.power_to_db(melspectrogram, ref=np.max)

# # Plot the figure
# fig, ax = plt.subplots(figsize=(12, 8), subplot_kw={'projection': 'polar'})

# # Define a list of features to plot
# features = [melspectrogram_db, chromagram, spectral_contrast, tonnetz, harmonic]
# feature_names = ['Mel-Spectrogram', 'Chromagram', 'Spectral Contrast', 'Tonnetz', 'Harmonic']

# # Define the radius increment for each concentric circle
# radius_increment = 0.1
# initial_radius = 0.1

# # Plot each feature on the polar plot
# for i, feature in enumerate(features):
#     # Normalize the feature between 0 and 1
#     feature_norm = (feature - np.min(feature)) / (np.max(feature) - np.min(feature))
   
#     # Define the radius for this feature
#     r = np.linspace(initial_radius + i * radius_increment, initial_radius + (i + 1) * radius_increment, feature.shape[0])

#     # Create theta (angle) with one additional point to close the loop
#     theta = np.linspace(0, 2 * np.pi, feature.shape[1] + 1)
    
#     # Repeat the first column of the feature to close the circle
#     feature_norm = np.hstack((feature_norm, feature_norm[:, [0]]))

#     # Create meshgrid for theta and r for plotting
#     R, Theta = np.meshgrid(r, theta)

#     # Plot the feature
#     ax.pcolormesh(Theta, R, feature_norm, shading='auto')  # Use 'auto' shading for a clean wrap

# # Set the plot's title
# ax.set_title('Polar Feature Visualization for "Smells Like Teen Spirit"', va='bottom')

# # Show the plot
# plt.show()

# %%
# import librosa
# import numpy as np
# import matplotlib.pyplot as plt

# # Load the audio file
# y, sr = librosa.load('09 Purple Rain.wav', sr=22050)  # Downsample to reduce size

# # Extract features with optimized parameters
# melspectrogram = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=64, hop_length=1024)
# chromagram = librosa.feature.chroma_stft(y=y, sr=sr, hop_length=1024)
# spectral_contrast = librosa.feature.spectral_contrast(y=y, sr=sr, n_bands=6, hop_length=1024)
# tonnetz = librosa.feature.tonnetz(y=y, sr=sr)
# harmonic, percussive = librosa.effects.hpss(y)

# # Convert to decibels for the melspectrogram
# melspectrogram_db = librosa.power_to_db(melspectrogram, ref=np.max).astype(np.float16)

# # Normalize and pad only necessary features
# features = [melspectrogram_db, chromagram, spectral_contrast, tonnetz, harmonic]
# features_padded = [np.pad(f, ((0,0), (0, max(0, 500 - f.shape[1]))), mode='constant', constant_values=0) for f in features]

# # Visualizing a portion to manage memory
# plt.figure(figsize=(10, 4))
# plt.imshow(features_padded[0], aspect='auto', origin='lower')
# plt.title('Reduced Melspectrogram')
# plt.colorbar()
# plt.show()

# %%
# non working visualizatiuon plot bar upload

# %%
# import librosa
# import numpy as np
# import matplotlib.pyplot as plt

# # Load the audio file
# y, sr = librosa.load('09 Purple Rain.wav', sr=None)

# # Extract features
# melspectrogram = librosa.feature.melspectrogram(y=y, sr=sr)
# chromagram = librosa.feature.chroma_stft(y=y, sr=sr)

# spectral_contrast = librosa.feature.spectral_contrast(y=y, sr=sr)
# tonnetz = librosa.feature.tonnetz(y=y, sr=sr)
# harmonic, percussive = librosa.effects.hpss(y)

# # Convert to decibels for the melspectrogram
# melspectrogram_db = librosa.power_to_db(melspectrogram, ref=np.max)

# # Assume the first dimension is time; find the max length
# max_length = max(melspectrogram_db.shape[1], chromagram.shape[1], spectral_contrast.shape[1], tonnetz.shape[1], harmonic.shape[0])  # Corrected for harmonic

# features = [melspectrogram_db, chromagram, spectral_contrast, tonnetz, harmonic]
# features_padded = []

# for feature in features:
#     # Normalize the feature
#     feature = (feature - np.min(feature)) / (np.max(feature) - np.min(feature))
    
#     # Determine padding based on feature dimensions
#     if len(feature.shape) == 1:  # It's a 1D array
#         pad_width = max_length - feature.shape[0]
#         feature_padded = np.pad(feature, pad_width=(0, pad_width), mode='constant', constant_values=0)
#         feature_padded = feature_padded[np.newaxis, :]  # Convert to 2D by adding an axis
#     else:  # It's already a 2D array
#         pad_width = max_length - feature.shape[1]
#         feature_padded = np.pad(feature, pad_width=((0, 0), (0, pad_width)), mode='constant', constant_values=0)
    
#     features_padded.append(feature_padded)

# # Plotting
# fig, ax = plt.subplots(figsize=(12, 8), subplot_kw={'projection': 'polar'})
# ax.axis('off')

# # Plot each feature with a different radius
# radius_increment = 0.2
# for i, feature in enumerate(features_padded):
#     radius_offset = i * radius_increment
#     theta = np.linspace(0, 2 * np.pi, feature.shape[1] + 1)
#     r = np.linspace(radius_offset, radius_offset + radius_increment, feature.shape[0] + 1)
#     theta, r = np.meshgrid(theta, r)
#     ax.pcolormesh(theta, r, feature, shading='flat')

# ax.set_ylim(0, radius_offset + radius_increment)
# ax.set_title('Concentric Circles Representing Different Audio Features', va='bottom')
# plt.show()
